# %%
# Подключение библиотек

from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.layers import Dense, Conv2D, BatchNormalization, Dropout, Input, GlobalAvgPool2D, GlobalMaxPool2D, concatenate
from tensorflow.keras.optimizers import Adam
from IPython.display import Audio
import wave
from joblib import Parallel, delayed
import librosa
from functools import partial
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Загрузка данных

train = pd.read_csv('train.csv')
train.head()
# Out:
#           fname         label  manually_verified
# 0  00044347.wav        Hi-hat                  0
# 1  001ca53d.wav     Saxophone                  1
# 2  002d256b.wav       Trumpet                  0
# 3  0033e230.wav  Glockenspiel                  1
# 4  00353774.wav         Cello                  1

# %%
file = '0b82b3a5.wav'
path = 'C:\\Users\\user\\OneDrive - Ltd.E-Promo\\Desktop\\Анализ звука и голоса\\audio_train\\'
Audio(filename=path+file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Нахождение длительности аудиофайлов и запись в датафрейм

def get_duration(file):
    return wave.open(path+file).getnframes()/wave.open(path+file).getframerate()

with Parallel(n_jobs=10, prefer='threads', verbose=0) as ex:
    durations = ex(delayed(get_duration)(e) for e in train['fname'])
    
train['duration'] = durations
train.head()
# Out:
#           fname         label  manually_verified  duration
# 0  00044347.wav        Hi-hat                  0     14.00
# 1  001ca53d.wav     Saxophone                  1     10.32
# 2  002d256b.wav       Trumpet                  0      0.44
# 3  0033e230.wav  Glockenspiel                  1      8.00
# 4  00353774.wav         Cello                  1      4.52

# %%
# Выбирание  аудифайлов, длительность которых не превышает 3 сеунды

train = train.loc[train['duration'] <= 3]
train.head()
# Out:
#            fname               label  manually_verified  duration
# 2   002d256b.wav             Trumpet                  0      0.44
# 6   003da8e5.wav               Knock                  1      1.36
# 7   0048fd00.wav  Gunshot_or_gunfire                  1      1.04
# 10  006f2f32.wav              Hi-hat                  1      1.68
# 12  00780200.wav          Snare_drum                  0      1.12

# %%
# Извлечение MFCC из аудио с использованием Librosa

y, sr = librosa.load(path+file)
mfcc = librosa.feature.mfcc(y, sr, n_mfcc=40)
print("librosa вычислила", mfcc.shape[0], "MFCC на", mfcc.shape[1], "-кадровом аудиосемпле")
plt.figure(figsize=(10,5))
plt.imshow(mfcc, cmap='hot');
# Out:
# librosa вычислила 40 MFCC на 95 -кадровом аудиосемпле

# %%
# Извлечение функций
def obtain_mfcc(file, features=40):
    y, sr = librosa.load(path+file, res_type='kaiser_fast')
    return librosa.feature.mfcc(y, sr, n_mfcc=features)

# %%
obtain_mfcc(file).shape
# Out:
# (40, 95)

# %%
mfcc.shape
# Out:
# (40, 95)

# %%
def get_mfcc(file, n_mfcc=40, padding=None):
    y, sr = librosa.load(path+file, res_type='kaiser_fast')
    mfcc = librosa.feature.mfcc(y, sr, n_mfcc=n_mfcc)
    if padding: mfcc = np.pad(mfcc, ((0, 0), (0, max(0, padding-mfcc.shape[1]))), 'constant')
    return mfcc.astype(np.float32)

mfcc = get_mfcc(file, padding=100)
print(mfcc.shape)
plt.figure(figsize=(12,5))
plt.imshow(mfcc, cmap='hot');
# Out:
# (40, 100)

# %%
# Нахождение padding для самого продолжительного файла
print(get_mfcc(train.sort_values('duration').fname.iloc[-1]).shape)
# Out:
# (40, 130)

# %%
# Преобразование данных для обучения

n_mfcc = 40
padding = 130
fun = partial(get_mfcc, n_mfcc=n_mfcc, padding=padding)

with Parallel(n_jobs=10, prefer='threads', verbose=0) as ex:
    mfcc_data = ex(delayed(partial(fun))(e) for e in train['fname'])
    
mfcc_data = np.stack(mfcc_data)[..., None]
mfcc_data.shape
# Out:
# (3936, 40, 130, 1)

# %%
mfcc_data
# Out:
# array([[[[-4.82412628e+02],
#          [-4.07738037e+02],
#          [-3.85441376e+02],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 9.47219391e+01],
#          [ 9.75328064e+01],
#          [ 1.02200790e+02],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-8.50574493e+01],
#          [-4.64571190e+01],
#          [-2.51263943e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[ 1.11257315e-01],
#          [ 2.60601807e+00],
#          [ 1.52873838e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-4.13889551e+00],
#          [-9.32245827e+00],
#          [-1.47865658e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-5.27465439e+00],
#          [-4.16694641e+00],
#          [-5.33019066e-01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]],
#
#
#        [[[-6.51030212e+02],
#          [-6.51844177e+02],
#          [-6.50922241e+02],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 3.46536350e+00],
#          [ 2.31360340e+00],
#          [ 3.59845400e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 3.44694090e+00],
#          [ 2.29322720e+00],
#          [ 3.52187347e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[-1.37774661e-01],
#          [ 2.90493816e-02],
#          [ 1.14778614e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-1.67389601e-01],
#          [ 2.72834301e-03],
#          [ 1.09235275e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-1.88818157e-01],
#          [-2.26550996e-02],
#          [ 1.00567031e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]],
#
#
#        [[[-4.95722900e+02],
#          [-4.71345367e+02],
#          [-4.41392578e+02],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 1.66609802e+01],
#          [ 2.26995258e+01],
#          [ 2.02747326e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 7.76149464e+00],
#          [-3.48110056e+00],
#          [-1.96347008e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[ 7.15238154e-01],
#          [ 2.53822684e+00],
#          [ 2.76150823e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 2.27744532e+00],
#          [-1.12061691e+00],
#          [ 3.45418501e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 2.21588612e+00],
#          [ 2.11286640e+00],
#          [ 1.74845028e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]],
#
#
#        ...,
#
#
#        [[[-1.69616760e+02],
#          [-7.73960114e+01],
#          [-1.58226900e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 1.36706268e+02],
#          [ 1.41715698e+02],
#          [ 1.36658066e+02],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-2.18284855e+01],
#          [-4.33311729e+01],
#          [-4.88335571e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[-1.24405766e+00],
#          [ 6.77970409e-01],
#          [-5.64001226e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-3.79575324e+00],
#          [-4.79851913e+00],
#          [-1.05706062e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 7.82005191e-01],
#          [ 1.08461118e+00],
#          [-2.91704106e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]],
#
#
#        [[[-2.48273830e+01],
#          [-3.03048515e+01],
#          [-5.66014061e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 8.32505417e+00],
#          [ 9.04985428e+00],
#          [ 7.16228104e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 1.20141325e+01],
#          [ 1.15248661e+01],
#          [ 9.19565201e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[-1.79300117e+00],
#          [ 1.83474147e+00],
#          [ 4.96915913e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-6.34608269e+00],
#          [-4.56758881e+00],
#          [-1.37644339e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-2.46284032e+00],
#          [-2.21730709e+00],
#          [-2.58958840e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]],
#
#
#        [[[-3.14009277e+02],
#          [-1.58945328e+02],
#          [-9.66406555e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 1.15227478e+02],
#          [ 8.80205994e+01],
#          [ 8.73881683e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-5.79329300e+01],
#          [-5.35550308e+01],
#          [-5.11429443e+01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         ...,
#
#         [[ 7.51065874e+00],
#          [ 2.86526060e+00],
#          [-2.48147058e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[-1.37372208e+00],
#          [ 5.79391956e-01],
#          [ 9.11625385e-01],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]],
#
#         [[ 3.99121308e+00],
#          [ 7.13494825e+00],
#          [ 4.14032888e+00],
#          ...,
#          [ 0.00000000e+00],
#          [ 0.00000000e+00],
#          [ 0.00000000e+00]]]], dtype=float32)

# %%
label_unique = list(train['label'].unique())
label_number = {label: i for i, label in enumerate(label_unique)}
train["label_number"] = train.label.map(label_number)

# %%
train.head()
# Out:
#            fname               label  manually_verified  duration  \
# 2   002d256b.wav             Trumpet                  0      0.44
# 6   003da8e5.wav               Knock                  1      1.36
# 7   0048fd00.wav  Gunshot_or_gunfire                  1      1.04
# 10  006f2f32.wav              Hi-hat                  1      1.68
# 12  00780200.wav          Snare_drum                  0      1.12
#
#     label_number
# 2              0
# 6              1
# 7              2
# 10             3
# 12             4

# %%
# Разделение данных на обучающие и тестовые

x_train, x_val, y_train, y_val = train_test_split(mfcc_data, train['label_number'], test_size=0.2, random_state=42)
x_train.shape, x_val.shape
# Out:
# ((3148, 40, 130, 1), (788, 40, 130, 1))

# %%
# Архитектура модели

m_in = Input([n_mfcc, padding, 1])
x = BatchNormalization()(m_in)

x = Conv2D(10, 3, strides=1, activation='relu', padding='same', use_bias=False, kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Dropout(0.02)(x)

x = Conv2D(20, 3, strides=(2,2), activation='relu', padding='same', use_bias=False, kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Dropout(0.02)(x)

x = Conv2D(50, 3, strides=(2,2), activation='relu', padding='same', use_bias=False, kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Dropout(0.02)(x)

x = Conv2D(100, 3, strides=(2,2), activation='relu', padding='same', use_bias=False, kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Dropout(0.02)(x)
    
x_avg = GlobalAvgPool2D()(x)
x_max = GlobalMaxPool2D()(x)

x = concatenate([x_avg, x_max])
x = Dense(1000, activation='relu', use_bias=False, kernel_initializer='he_uniform')(x)
x = Dropout(0.2)(x)
m_out = Dense(len(label_unique), activation='softmax')(x)

model_1 = Model(m_in, m_out)
model_1.compile(Adam(0.002), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 40, 130, 1)  0           []
#                                 ]
#
#  batch_normalization (BatchNorm  (None, 40, 130, 1)  4           ['input_1[0][0]']
#  alization)
#
#  conv2d (Conv2D)                (None, 40, 130, 10)  90          ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 40, 130, 10)  40         ['conv2d[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 40, 130, 10)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 20, 65, 20)   1800        ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 20, 65, 20)  80          ['conv2d_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 20, 65, 20)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 33, 50)   9000        ['dropout_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 10, 33, 50)  200         ['conv2d_2[0][0]']
#  rmalization)
#
#  dropout_2 (Dropout)            (None, 10, 33, 50)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 5, 17, 100)   45000       ['dropout_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 5, 17, 100)  400         ['conv2d_3[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 5, 17, 100)   0           ['batch_normalization_4[0][0]']
#
#  global_average_pooling2d (Glob  (None, 100)         0           ['dropout_3[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 100)         0           ['dropout_3[0][0]']
#  xPooling2D)
#
#  concatenate (Concatenate)      (None, 200)          0           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 1000)         200000      ['concatenate[0][0]']
#
#  dropout_4 (Dropout)            (None, 1000)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 41)           41041       ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 297,655
# Trainable params: 297,293
# Non-trainable params: 362
# __________________________________________________________________________________________________

# %%
score = model_1.evaluate(x_train, y_train, verbose=0)
print("Точность модели перед тренировкой", 100*score[1])
# Out:
# Точность модели перед тренировкой 2.0648030564188957

# %%
# %%time
# K.eval(model_1.optimizer.lr.assign(0.0003))
model_1.fit(x_train, y_train, 64, 50, validation_data=[x_val, y_val])
# Out:
# Epoch 1/50
# 50/50 [==============================] - 9s 173ms/step - loss: 3.9735 - accuracy: 0.2640 - val_loss: 3.0260 - val_accuracy: 0.2602
# Epoch 2/50
# 50/50 [==============================] - 10s 202ms/step - loss: 1.9632 - accuracy: 0.4794 - val_loss: 2.8812 - val_accuracy: 0.2221
# Epoch 3/50
# 50/50 [==============================] - 10s 199ms/step - loss: 1.5883 - accuracy: 0.5588 - val_loss: 2.3327 - val_accuracy: 0.3604
# Epoch 4/50
# 50/50 [==============================] - 10s 203ms/step - loss: 1.3681 - accuracy: 0.6188 - val_loss: 1.8057 - val_accuracy: 0.4949
# Epoch 5/50
# 50/50 [==============================] - 11s 219ms/step - loss: 1.1676 - accuracy: 0.6693 - val_loss: 1.5907 - val_accuracy: 0.5635
# Epoch 6/50
# 50/50 [==============================] - 13s 255ms/step - loss: 1.0392 - accuracy: 0.6995 - val_loss: 1.4844 - val_accuracy: 0.5901
# Epoch 7/50
# 50/50 [==============================] - 11s 221ms/step - loss: 0.8721 - accuracy: 0.7408 - val_loss: 1.3052 - val_accuracy: 0.6637
# Epoch 8/50
# 50/50 [==============================] - 12s 233ms/step - loss: 0.8120 - accuracy: 0.7592 - val_loss: 1.1959 - val_accuracy: 0.6764
# Epoch 9/50
# 50/50 [==============================] - 12s 237ms/step - loss: 0.6758 - accuracy: 0.7951 - val_loss: 1.1873 - val_accuracy: 0.7069
# Epoch 10/50
# 50/50 [==============================] - 12s 235ms/step - loss: 0.5871 - accuracy: 0.8227 - val_loss: 1.1769 - val_accuracy: 0.7069
# Epoch 11/50
# 50/50 [==============================] - 11s 215ms/step - loss: 0.5176 - accuracy: 0.8342 - val_loss: 1.2439 - val_accuracy: 0.6777
# Epoch 12/50
# 50/50 [==============================] - 11s 222ms/step - loss: 0.4561 - accuracy: 0.8494 - val_loss: 1.3625 - val_accuracy: 0.6853
# Epoch 13/50
# 50/50 [==============================] - 11s 229ms/step - loss: 0.4195 - accuracy: 0.8691 - val_loss: 1.2632 - val_accuracy: 0.7132
# Epoch 14/50
# 50/50 [==============================] - 11s 223ms/step - loss: 0.4028 - accuracy: 0.8710 - val_loss: 1.7020 - val_accuracy: 0.6218
# Epoch 15/50
# 50/50 [==============================] - 11s 225ms/step - loss: 0.3841 - accuracy: 0.8755 - val_loss: 1.4802 - val_accuracy: 0.7005
# Epoch 16/50
# 50/50 [==============================] - 12s 233ms/step - loss: 0.3568 - accuracy: 0.8834 - val_loss: 1.3134 - val_accuracy: 0.7081
# Epoch 17/50
# 50/50 [==============================] - 12s 245ms/step - loss: 0.3316 - accuracy: 0.8958 - val_loss: 1.4492 - val_accuracy: 0.7145
# Epoch 18/50
# 50/50 [==============================] - 13s 266ms/step - loss: 0.3048 - accuracy: 0.9015 - val_loss: 1.4085 - val_accuracy: 0.6916
# Epoch 19/50
# 50/50 [==============================] - 14s 279ms/step - loss: 0.2812 - accuracy: 0.9060 - val_loss: 1.4637 - val_accuracy: 0.6992
# Epoch 20/50
# 50/50 [==============================] - 14s 279ms/step - loss: 0.2415 - accuracy: 0.9165 - val_loss: 1.4186 - val_accuracy: 0.7170
# Epoch 21/50
# 50/50 [==============================] - 13s 253ms/step - loss: 0.1948 - accuracy: 0.9342 - val_loss: 1.3951 - val_accuracy: 0.7132
# Epoch 22/50
# 50/50 [==============================] - 12s 246ms/step - loss: 0.2240 - accuracy: 0.9206 - val_loss: 1.4605 - val_accuracy: 0.7157
# Epoch 23/50
# 50/50 [==============================] - 12s 250ms/step - loss: 0.2376 - accuracy: 0.9206 - val_loss: 1.9519 - val_accuracy: 0.6637
# Epoch 24/50
# 50/50 [==============================] - 14s 274ms/step - loss: 0.2793 - accuracy: 0.9203 - val_loss: 1.6980 - val_accuracy: 0.6992
# Epoch 25/50
# 50/50 [==============================] - 15s 300ms/step - loss: 0.2217 - accuracy: 0.9269 - val_loss: 1.5548 - val_accuracy: 0.7195
# Epoch 26/50
# 50/50 [==============================] - 13s 258ms/step - loss: 0.2028 - accuracy: 0.9339 - val_loss: 1.7571 - val_accuracy: 0.7005
# Epoch 27/50
# 50/50 [==============================] - 13s 261ms/step - loss: 0.1612 - accuracy: 0.9489 - val_loss: 1.5652 - val_accuracy: 0.7259
# Epoch 28/50
# 50/50 [==============================] - 13s 269ms/step - loss: 0.1192 - accuracy: 0.9587 - val_loss: 1.6798 - val_accuracy: 0.7221
# Epoch 29/50
# 50/50 [==============================] - 14s 287ms/step - loss: 0.1911 - accuracy: 0.9390 - val_loss: 1.5341 - val_accuracy: 0.7272
# Epoch 30/50
# 50/50 [==============================] - 12s 249ms/step - loss: 0.1098 - accuracy: 0.9657 - val_loss: 1.5029 - val_accuracy: 0.7335
# Epoch 31/50
# 50/50 [==============================] - 13s 251ms/step - loss: 0.0940 - accuracy: 0.9730 - val_loss: 1.6247 - val_accuracy: 0.7246
# Epoch 32/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.1170 - accuracy: 0.9616 - val_loss: 1.6447 - val_accuracy: 0.7424
# Epoch 33/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.1810 - accuracy: 0.9416 - val_loss: 2.0157 - val_accuracy: 0.6726
# Epoch 34/50
# 50/50 [==============================] - 14s 275ms/step - loss: 0.1383 - accuracy: 0.9539 - val_loss: 1.6763 - val_accuracy: 0.7246
# Epoch 35/50
# 50/50 [==============================] - 12s 231ms/step - loss: 0.1532 - accuracy: 0.9530 - val_loss: 1.8227 - val_accuracy: 0.7246
# Epoch 36/50
# 50/50 [==============================] - 13s 269ms/step - loss: 0.1599 - accuracy: 0.9495 - val_loss: 1.8462 - val_accuracy: 0.7208
# Epoch 37/50
# 50/50 [==============================] - 13s 253ms/step - loss: 0.1401 - accuracy: 0.9568 - val_loss: 1.9504 - val_accuracy: 0.7030
# Epoch 38/50
# 50/50 [==============================] - 12s 243ms/step - loss: 0.1142 - accuracy: 0.9606 - val_loss: 1.8002 - val_accuracy: 0.7272
# Epoch 39/50
# 50/50 [==============================] - 11s 226ms/step - loss: 0.1088 - accuracy: 0.9641 - val_loss: 1.8227 - val_accuracy: 0.7310
# Epoch 40/50
# 50/50 [==============================] - 11s 227ms/step - loss: 0.1149 - accuracy: 0.9628 - val_loss: 2.0033 - val_accuracy: 0.7132
# Epoch 41/50
# 50/50 [==============================] - 12s 239ms/step - loss: 0.1140 - accuracy: 0.9660 - val_loss: 1.8167 - val_accuracy: 0.7360
# Epoch 42/50
# 50/50 [==============================] - 12s 236ms/step - loss: 0.1145 - accuracy: 0.9622 - val_loss: 2.0484 - val_accuracy: 0.7284
# Epoch 43/50
# 50/50 [==============================] - 12s 232ms/step - loss: 0.0818 - accuracy: 0.9755 - val_loss: 1.9339 - val_accuracy: 0.7246
# Epoch 44/50
# 50/50 [==============================] - 12s 231ms/step - loss: 0.0683 - accuracy: 0.9809 - val_loss: 1.8612 - val_accuracy: 0.7360
# Epoch 45/50
# 50/50 [==============================] - 11s 222ms/step - loss: 0.1078 - accuracy: 0.9692 - val_loss: 1.9707 - val_accuracy: 0.7145
# Epoch 46/50
# 50/50 [==============================] - 11s 219ms/step - loss: 0.1437 - accuracy: 0.9587 - val_loss: 2.0117 - val_accuracy: 0.7183
# Epoch 47/50
# 50/50 [==============================] - 12s 244ms/step - loss: 0.1165 - accuracy: 0.9638 - val_loss: 2.1142 - val_accuracy: 0.7145
# Epoch 48/50
# 50/50 [==============================] - 12s 239ms/step - loss: 0.1700 - accuracy: 0.9425 - val_loss: 2.0172 - val_accuracy: 0.7132
# Epoch 49/50
# 50/50 [==============================] - 11s 227ms/step - loss: 0.1311 - accuracy: 0.9593 - val_loss: 2.1131 - val_accuracy: 0.7132
# Epoch 50/50
# 50/50 [==============================] - 11s 230ms/step - loss: 0.1225 - accuracy: 0.9622 - val_loss: 2.0249 - val_accuracy: 0.7195
# Wall time: 10min 2s

# %%
score = model_1.evaluate(x_train, y_train, verbose=0)
print("Точность обучения: {0:.2%}".format(score[1]))
score = model_1.evaluate(x_val, y_val, verbose=0)
print("Точность тестирования: {0:.2%}".format(score[1]))
# Out:
# Точность обучения: 98.86%
# Точность тестирования: 71.95%
